# %% [markdown]
# Project plan => software crreate
# login krte hi 3 options ayenge :
# 1 -> Named entity recognition => like in one         paragraph search konsa language use hua hai
# 2 -> language -> hindi,english,bangla etc.
# 3 -> sentimenta analysis => text inpute => sad ,happy etc.

# %%
# !pip install nlpcloud # (!)denotes => command

# %%
import nlpcloud
class NLPApp:

  def __init__(self):

    self.__database = {}
    self.__first_menu()

  def __first_menu(self):

    first_input = input("""
    Hi! how would you like to proceed?
    1. Not a member? Register
    2. Already a member? Login
    3. Galti se aa gaye? Exit
    """)

    if first_input == '1':
      self.__register()
    elif first_input =='2':
      self.__login()
    else:
      exit()

  def __second_menu(self):

    second_input = input("""
    Hi! how would you like to proceed?
    1. NER
    2. Language Detection
    3. Sentiment Analysis
    """)

    if second_input == '1':
      self.__ner()
    elif second_input =='2':
      self.__language_detection()
    elif second_input =='3':
      self.__sentiment_analysis()
    else:
      exit()

  def __register(self):
    name = input('enter name')
    email = input('enter email')
    password = input('enter password')

    if email in self.__database:
      print('email alreadt exists ')

    else:
      self.__database[email] = [name,password]
      print('rgistration successful.Now login')
      print(self.__database)
      self.__first_menu()

  def __login(self):

    email = input('enter email')
    password = input('enter password')

    if email in self.__database:
      if self.__database[email][1] == password:
        print('login successful')
        self.__second_menu()
      else:
        print('password incorrect.Try again')
        self.__login()
    else:
      print('This email is not registered')
      self.__first_menu()

  def __ner(self):
    para = input('enter the paragraph')
    search_term = input('what would you like to search') # Added search_term input

    client = nlpcloud.Client("finetuned-gpt-neox-20b", "444bffd52cf1498c6059a0d4e40acfacf6983769", gpu=True, lang="en")
    response = client.entities(para,searches_entity =search_term)

    print(response)

  def __language_detection(self):
    # Placeholder for language detection logic
    print('Language Detection functionality goes here.')

  def __sentiment_analysis(self):
    # Placeholder for sentiment analysis logic
    print('Sentiment Analysis functionality goes here.')

obj = NLPApp()
# Out:
#     Hi! how would you like to proceed?
#     1. Not a member? Register
#     2. Already a member? Login
#     3. Galti se aa gaye? Exit
#     1
# enter nameaku
# enter emailaku@gmail.com
# enter password1234
# rgistration successful.Now login
# {'aku@gmail.com': ['aku', '1234']}
#
#     Hi! how would you like to proceed?
#     1. Not a member? Register
#     2. Already a member? Login
#     3. Galti se aa gaye? Exit
#     1
# enter namerahul
# enter emailrahul@gmail.com
# enter password5678
# rgistration successful.Now login
# {'aku@gmail.com': ['aku', '1234'], 'rahul@gmail.com': ['rahul', '5678']}
#
#     Hi! how would you like to proceed?
#     1. Not a member? Register
#     2. Already a member? Login
#     3. Galti se aa gaye? Exit
#     2
# enter emailrahul
# enter passwordrahul@gmail.com
# This email is not registered
#
#     Hi! how would you like to proceed?
#     1. Not a member? Register
#     2. Already a member? Login
#     3. Galti se aa gaye? Exit
#     3

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 9.9 MB/s eta 0:00:00
# ...
