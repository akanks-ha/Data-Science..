# %% [markdown]
# # **Write OOP classes to handle the following scenarios:**
#
#
#
# *   A user can create and view 2D coordinates
#
# *  A user can find out the distance between 2 coordinates
#
# *   A user can find out the distance of a coordinate from origin
#
# *   A user can check if a point lies on a given line
#
#
# *   A user can find the distance between a given 2D point and a given line

# %%
class Point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (sself.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    return(self.x_cod**2 + self.y_cod**2)**0.5
    # return self.euclidean_distance(Point(0,0))

class Line:
  def __init__(self,A,B,C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
      return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

  def point_on_line(line,point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return "lies on the line"
    else:
      return "does not lie on the line"
  def shortest_distance(line,point):
    return abs(line.A*point.x_cod + line.B*point.y_cod + line.C)/(line.A**2 + line.B**2)**0.5

# %%
p1 = Point(0,0)
p2 = Point(1,1)
#<x,y>
# print(p1)
# print(p2)
p2.distance_from_origin()
# p1.euclidean_distance(p2)
# Out:
# 1.4142135623730951

# %%
l1 = Line(3,4,5)
print(l1)
# Out:
# 3x + 4y + 5 = 0

# %%
l1 = Line(1,1,-2)
p1 = Point(1,1)
print(l1)
print(p1)

# l1.point_on_line(p1)
l1.shortest_distance(p1)
# Out:
# 1x + 1y + -2 = 0
# <1,1>
# 0.0

# %% [markdown]
# # **How objects access atributes**

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country =='india':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
# How to access attrinutes
p = Person('nitish','india')

# %%
p.country
# Out:
# 'india'

# %%
p.greet()
# Out:
# Namaste nitish

# %%
# what if i try ti access non - existent attributes
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12865/3167917604.py in <cell line: 0>()
#       1 # what if i try ti access non - existent attributes
# ----> 2 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# # **Attributes creation from outside of the class**

# %%
p.gender = 'male'

# %%
p.gender
# Out:
# 'male'

# %% [markdown]
# # **Reference Variables**
# * Reference variables hold the objects
# * We can create objects wothout reference variable as well
# * An object can have multiple reference variables
# * Assignimg a new reference variable to an eisting object does not create a new object

# %%
# object without a refrence
class Person:

  def __init__(self):
    self.name = 'aku'
    self.gender = 'female'

# Person() # creation object
p = Person() # p is a reference varible which is contain  the address of (Person) object that has been created
q = p

# %%
# multiple ref
print(id(p))
print(id(q))
# Out:
# 136580921666176
# 136580921666176

# %%
# chnage attribute value with help of 2nd object

# %%
print(p.name)
print(q.name)
q.name = 'rahul'
print(p.name)
print(q.name)
# Out:
# aku
# aku
# rahul
# rahul

# %% [markdown]
# # Pass by reference

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)
  p1 = Person('ankit','male') # function returning object
  return p1                    #

p = Person('aku','female')
x = greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is aku and I am a female
# ankit
# male

# %% [markdown]
# # **Object ki mutability**

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  # print('Hi my name is',person.name,'and I am a',person.gender)
  person.name = 'rahul'
  # print(person.name)
  return person


p = Person('aku','female')
print(id(p))
p1 = greet(p) # address same so object is mutable(user defined objects are mutable just like list,set,dictinaries)
print(p.name)
print(id(p1))
# Out:
# 136580921663488
# 136580921663488
# rahul
# 136580921663488

# %% [markdown]
# # **Encapsulation**
# data aur uske do method ko mila diya gya setter and getter ko mila diya gya khte hai encapsulation

# %%
# instance var -> (ek aisa variable jiska value alag alag objects ke liye alag alag hota hai) # check on python tutor
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

p1 = Person('aku','india')
p2 = Person('rahul','india')

# %%
p1.name
p2.name
# Out:
# 'rahul'

# %%
class Atm:
  # constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot marenge')



  def __menu(self):
   user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
   if user_input =='1':
    # create pin
    self.create_pin()

   elif user_input =='2':
        # change pin
        self.change_pin()

   elif user_input =='3':
    # check balance
    self.check_balance()

   elif user_input == '4':
    #withdraw
    self.withdraw()
   else:
    exit()


  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance =  int(input('enter balance'))
    self.__balance = user_balance

    print('pin created succesfully')



  def change_pin(self):
    old_pin = input('enter old pin')
    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successfully')
      self.menu()
    else:
      print('nai krnde de skta re baba')
      self.menu()


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is',self.__balance)

    else:
      print('chal nikal yha se')



  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')

    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 136580921668576

# %%
# obj.balance = 'hehehe'
# obj.__balance = 'hehehe' => not showing any erro bc he is working on another

# %%
obj.create_pin()
obj._Atm__balance = 'hehehe' # from here we can say that in python nothing will be trully private you can change private varible as well
# Out:
# enter your pin1234
# enter balance1000
# pin created succesfully

# %%
obj.__balance = 'hehehe'

# %%
obj.check_balance()
# Out:
# enter your pin1234
# your balance is hehehe

# %%
# obj.set_balance('hehehe')
obj.set_balance(1000)

# %%
obj.get_balance()
# Out:
# 1000

# %%
obj.withdraw()
# Out:
# enter the pin1234
# enter the amount400
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12865/3797629794.py in <cell line: 0>()
# ----> 1 obj.withdraw()
#
# /tmp/ipykernel_12865/2313944707.py in withdraw(self)
#      75       # allow to withdraw
#      76       amount = int(input('enter the amount'))
# ---> 77       if amount <= self.__balance:
#      78         self.__balance = self.__balance - amount
#      79         print('withdrawl successful.balance is',self.__balance)
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %% [markdown]
#  make all attribute private =>
#
#  when he was make __balance then on memory _Atm__balance create memory me alag vaible bn gya
#
#  when you have make atribute private when your junior has change balance amount hehehe then he is working on another attribute which is not exist on the class

# %% [markdown]
# # **Collection of objects**

# %%
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

L = [p1,p2,p3]


for i in L:
  print(i.name,i.gender)
# Out:
# nitish male
# ankit male
# ankita female

# %%
# dict of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

d = {'p1':p1,'p2':p2,'p3':p3}


for i in d:
  print(d[i].name,d[i].gender)
# Out:
# nitish male
# ankit male
# ankita female

# %% [markdown]
# # **Static Variables(Vs Instance vaiable)**

# %%
# need for static variable

# %%
class Atm:

  __counter = 1

  # constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter
    # self.cid+=1
    Atm.__counter = Atm.__counter + 1

  # utility functions
  @staticmethod # do not need to creata any object to access
  def get_counter():
    return Atm.__counter

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot marenge')



  def __menu(self):
   user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
   if user_input =='1':
    # create pin
    self.create_pin()

   elif user_input =='2':
        # change pin
        self.change_pin()

   elif user_input =='3':
    # check balance
    self.check_balance()

   elif user_input == '4':
    #withdraw
    self.withdraw()
   else:
    exit()


  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance =  int(input('enter balance'))
    self.__balance = user_balance

    print('pin created succesfully')



  def change_pin(self):
    old_pin = input('enter old pin')
    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successfully')
      self.menu()
    else:
      print('nai krnde de skta re baba')
      self.menu()


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is',self.__balance)

    else:
      print('chal nikal yha se')



  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')

    else:
      print('sale chor')

# %%
c1 = Atm() # error make private
# Out:
# 136580921661712

# %%
c2 = Atm()
# Out:
# 136580921657824

# %%
c3 = Atm()
# Out:
# 136580921428256

# %%
# c1.cid
# c1.get_counter() # error => c1 self ko receive nhi kr rha
Atm.get_counter() # is time ke method ko withour self to acces call with the name of class
# Out:
# 2

# %%
c2.cid
# Out:
# 2

# %%
c3.cid
# Out:
# 3

# %%
Atm.counter
# Out:
# 4

# %% [markdown]
# instance variable -> har object ke liye alg value hoti hai , instance varible object ka variable hota hai
#
# static varible class ka varible  hota hai => static variable ka value har object ke liye same hota hai
#
# (class name.varible name  => static varible (Atm.counter)
#
# likha jata hai class ke andr but ouside the method)
#
#
#
# (object.varible name    => instance variable(self.cid)
#
# likha jta hai constructor ke andr)

# %%
Atm.counter = 'hehehe'
