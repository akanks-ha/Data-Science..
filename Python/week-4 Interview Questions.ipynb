# %% [markdown]
# # What is a mudule?
#
# Any file with an extension of .py is called a module in python.
#  Whenever we execute a program it's mudule name is` __main__` and this name is stored in` __name__`varible
#
#
# hr file jab apne me run hoti hai tb vo main ke name se run hoti hai but jab khi import hoti hai to vo apne file name se run hoti hai

# %%
def display():
  print('hello')

display()
print(__name__)
# Out:
# hello
# __main__

# %% [markdown]
# # Importing a module
# * But what is the need  to importt a module?
# * How to import a module

# %%
# # import a module
# import test
# test.hello('aku')

# %%
# import multiple module -> user defined + builtin
import math
# import test
# test.hello('aku')
print(math.floor(4.3))
# Out:
# 4

# %%
# show builtin modules

# %% [markdown]
# # Variations of import statement

# %%
# normal
import math
import random

# %%
# clubbing together
import math,random,test

# %%
# import specific names from module
from math import factorial
# from test import hello

factorial(5)
# Out:
# 120

# %%
# renaming modules
import math as m
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from math import factorial as f
f(5)
# Out:
# 120

# %% [markdown]
# # Order of execution of module

# %%
import sys
for p in sys.path:
  print(p)
# Out:
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# if `__name__= __main__`

# %% [markdown]
# # What are packages in Python
#
# A package in python is a directory containing similar sub package and modules
# * A particular directory is treated as package if it has `__init__.py` file in it.
# * The `__init__.py` file may be empty or contain some initialization code related to the package

# %% [markdown]
# # What are 3rd party package
#
# * The python community creates package and make it available for other    programmers
# * PyPi -> python package index
# * You can upload your own package
# * You can install from PyPI and install using pip
# *
