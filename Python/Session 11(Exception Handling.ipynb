# %% [markdown]
# There are 2 stages hwere error may happen in a program
# * During compilation -> Syntax Error
# * During execution -> Exception

# %% [markdown]
# Syntax Error
# * Something in the program is not written according to the programer.
# * Error is raised by the interpreter/compiler
# * You can solve it by rectifying the program

# %%
# Example
print 'hello world'
# Out:
#   File "/tmp/ipykernel_1538/2666085722.py", line 2
#     print 'hello world'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# Other example of syntax error
# * Leaving symbols like colon,brackets
# * Misspelling a keyword
# * Incorrect indentation
# empty if/else/loops/class/functions

# %%
a = 5
if a==3
 print('hello')
# Out:
#   File "/tmp/ipykernel_1538/1241991754.py", line 2
#     if a==3
#            ^
# SyntaxError: expected ':'

# %%
a = 5
iff a ==3
  print('hello')
# Out:
#   File "/tmp/ipykernel_1538/2674310516.py", line 2
#     iff a ==3
#         ^
# SyntaxError: invalid syntax

# %%
# IndexError => The IndexError is thrown when trying to access an item at an #invalid index.
L = [1,2,3]
L[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1538/2228319446.py in <cell line: 0>()
#       1 # IndexError => The IndexError is thrown when trying to access an item at an invalid index.
#       2 L = [1,2,3]
# ----> 3 L[100]
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
math.floor(5,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1538/3651088311.py in <cell line: 0>()
#       1 # ModuleNotFoundError
#       2 # The ModuleNotFoundError is thrown when a module could not be found.
# ----> 3 import mathi
#       4 math.floor(5,3)
#
# ModuleNotFoundError: No module named 'mathi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# KeyError
# The KeyError is thrown when a key is not found
d = {'name':'nitish'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1538/3138684723.py in <cell line: 0>()
#       2 # The KeyError is thrown when a key is not found
#       3 d = {'name':'nitish'}
# ----> 4 d['age']
#
# KeyError: 'age'

# %%
# TypeError
# The KeyError is thrown when an opearation or function is applied to an object of an inapropriate type
1 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/2098235361.py in <cell line: 0>()
#       1 # TypeError
#       2 # The KeyError is thrown when an opearation or function is applied to an object of an inapropriate type
# ----> 3 1 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#ValueError
# The ValueError is thrown when a funtion's argument is of an inappripriate type.
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1538/1624382594.py in <cell line: 0>()
#       1 #ValueError
#       2 # The ValueError is thrown when a funtion's argument is of an inappripriate type.
# ----> 3 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# NameErro
# The NameError is htrown when an object could not be found.
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/1097441700.py in <cell line: 0>()
#       1 # NameErro
#       2 # The NameError is htrown when an object could not be found.
# ----> 3 print(k)
#
# NameError: name 'k' is not defined

# %%
# AttributeError
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1538/2484895562.py in <cell line: 0>()
#       1 # AttributeError
#       2 L = [1,2,3]
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# # Exceptions
#
# If things go wrong during the execution of the program(runtime).It generally happens when somehting unforeseen has happend
# * Exception are raused by python runtime
# * You have to take is on the fly
#
# Examples
# * Memory overflow
# * Devide by 0 -> logical error
# * Database error

# %%
# Why is it important to handle exceptions
# how to handle exceptions
# -> Try catch block

# %%
# let's creste a file
with open('sample.txt','w') as f:
  f.write('hello world')

# %%
# try catch demo
# with open('sample.txt','r') as f:
#   print(f.read())

try:
  with open('sample1.txt','r') as f:
    print(f.read())
except:
  print('sorry file not found')
# Out:
# hello world

# %%
# AttributeError
L = [1,2,3]
L.upper()

# Stacktrace
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_724/246304454.py in <cell line: 0>()
#       1 # AttributeError
#       2 L = [1,2,3]
# ----> 3 L.upper()
#       4
#       5 # Stacktrace
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# catching specific exceptions
try:
  f = open('sample.txt','r')
  print(f.read())
  # print(m)
  L = [1,2,3]
  L[100]
except FileNotFoundError:
  print('file not found')
except NameError:
  print('varibale not defined')
except Exception as e:
  print(e)
# Out:
# hello world
# list index out of range

# %%
# else
try:
  f = open('sample1.txt','r')
except FileNotFoundError:
  print('file nai mili')
except Exception:
  print('kuch to lafda hai')
else:
  print(f.read())
# Out:
# file nai mili

# %%
# finally
try:
  f = open('sample1.txt','r')
except FileNotFoundError:
  print('file nai mili')
except Exception:
  print('kuch to lafda hai')
else:
  print(f.read())
finally:
  print('ye to print hoga hi')
# Out:
# file nai mili
# ye to print hoga hi

# %%
# raise Exception
# In Python programming ,exceptiob are raised when errors occure at runtime.
# We can also manually raise excpetions using the raise keyword.

# We can optionally pass values to the exception to clarify why that exception was raised

# %%
raise NameError('hello')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_724/1964080736.py in <cell line: 0>()
# ----> 1 raise NameError('hello')
#
# NameError: hello

# %%
class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise Exceptions('amount cannot be  -ve')
    if self.balance < amount:
      raise Exceptions('paise nai hai tere pas')
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(15000)
except Exception as e:
  print(e)
else:
  print(obj.balance)
# Out:
# name 'Exceptions' is not defined

# %%
class MyException(Exception):

  def __init__(self,message):
    print('message')

class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise MyExceptions('amount can not be -ve')
    if self.balance < amount :
      raise MyException('paise nai tere pas')
      self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(15000)
except MyException as e :
  pass
else:
  print(obj.balance)
# Out:
# message

# %% [markdown]
# Java->
#
# * try -> try
# * except -> catch
# * raise -> throw

# %%
# creatig custom exceptions  -> full control
# exceptions hierarchy in python

# %%
# simple example

# %%
class SecurityError(Exception):

  def __init__(self,message):
    print(message)

  def logout(self):
    print('logout')


class Google:

  def __init__(self,name,email,password,device):
    self.name = name
    self.email = email
    self.password = password
    self.device = device

  def login(self,email,password,device):
    if device != self.device:
      raise SecurityError
    if email == self.email and password == self.password:
      print('welcome')
    else:
      print('login error')


obj = Google('nitish','nitish@gmail.com','1234','android')
try :
  obj.login('nitish@gmail.com','1234','windows')
except SecurityError as e:
  e.logout()
else:
  print(obj.name)
finally:
  print('database conncetion closed')
# Out:
# database conncetion closed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_724/2217992994.py in <cell line: 0>()
#      27 obj = Google('nitish','nitish@gmail.com','1234','android')
#      28 try :
# ---> 29   obj.login('nitish@gmail.com','1234','windows')
#      30 except SecurityError as e:
#      31   e.logout()
#
# /tmp/ipykernel_724/2217992994.py in login(self, email, password, device)
#      18   def login(self,email,password,device):
#      19     if device != self.device:
# ---> 20       raise SecurityError
#      21     if email == self.email and password == self.password:
#      22       print('welcome')
#
# TypeError: SecurityError.__init__() missing 1 required positional argument: 'message'
