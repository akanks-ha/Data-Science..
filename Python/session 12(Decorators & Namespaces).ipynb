# %% [markdown]
# # Namespaces
#
# A namespaces is a space that holds name(identifiers).Programmatically speaking,namespaces are dictionary of identifiers(keys) and their objects(values)
#
# There are 4 types of namespace:
# * Builtin Namespace
# * Flobal Namespace
# * Enclosing Namespaces
# * Local Namespaces

# %% [markdown]
# # Scope and LEGB Rule
# A scope is a textual region of a Python program where a namespace is directly accessible.
# The interpreter searches for a name from the inside out,looking in the local,enclosing,global,and finally the built-in scope.If the interpreter doesn't find t Nameerror execution.

# %%
# local and global
a = 2

def temp():
  b = 3
  print(b)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global -> same name
a = 2

def temp():
  # local var
  a = 3
  print(b)

temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1033/3458268908.py in <cell line: 0>()
#       7   print(b)
#       8
# ----> 9 temp()
#      10 print(a)
#
# /tmp/ipykernel_1033/3458268908.py in temp()
#       5   # local var
#       6   a = 3
# ----> 7   print(b)
#       8
#       9 temp()
#
# NameError: name 'b' is not defined

# %%
# local and global -> local does not have but global has
a = 2

def temp():
  # local var
  print(a)
temp()
print(a)
# Out:
# 2
# 2

# %%
# local and global -> editing global
a = 2

def temp():
  # local var
  a += 1 # changes not allowed ypou can print and  read
  print(a)

temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_1033/1068045873.py in <cell line: 0>()
#       7   print(a)
#       8
# ----> 9 temp()
#      10 print(a)
#
# /tmp/ipykernel_1033/1068045873.py in temp()
#       4 def temp():
#       5   # local var
# ----> 6   a += 1 # changes not allowed ypou can print and  read
#       7   print(a)
#       8
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
# but in python
a = 2

def temp():
  # local var
  global a
  a += 1
  print(a)

temp()
print(a)
# Out:
# 3
# 3

# %%
# local and  global -> global created inside local
def temp():
  # local var
  global a
  a = 1
  print(a)

temp()
print(a)
# Out:
# 1
# 1

# %%
# local and  global -> function parameter is local
def temp(z):
  # local var
  print(z)

a = 5
temp(5)
print(a)
print(z)
# Out:
# 5
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1033/3911884610.py in <cell line: 0>()
#       7 temp(5)
#       8 print(a)
# ----> 9 print(z)
#
# NameError: name 'z' is not defined

# %%
# built-in scope
# print('hello')
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# how to see all the built-in
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# remaining built-ins
L = [1,2,3]

def max():
  print('hello')

max(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1033/958540473.py in <cell line: 0>()
#       5   print('hello')
#       6
# ----> 7 max(L)
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
# Enclosing Scope
def outer():
  def inner():
    print('inner function')
  inner()
  print('outer funtion')
outer()
print('main program')
# Out:
# inner function
# outer funtion
# main program

# %%
def outer():
  a = 3
  def inner():
    a = 4
    print(a)
  inner()
  print('outer funtion')
a = 1
outer()
print('main program')
# Out:
# 4
# outer funtion
# main program

# %% [markdown]
#  local -> Enclosing -> global -> built in  .. search value steps

# %%
# nonlocal keyword
def outer():
  a = 1
  def inner():
    nonlocal a
    a += 1
    print('inner',a)
  inner()
  print('outer',a)
outer()
print('main program')
# Out:
# inner 2
# outer 2
# main program

# %% [markdown]
# # summary
# namespace is dictionary varible name and
#
#
# main program --> local scope.
#
#
# two nested -> outer funtion -> enclosing scope -> inner function ->local scope
# already available -> bnuilt in scope

# %% [markdown]
# # Decorators
#
# A decorator in python is a function that receive another funtion as input and adds some functionality(decoration) to and it and return it.
#
# This can happenf only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# * Built in decorators like @ staticmethod,@classmethod,@abstractmethod and @property etc
# * user defined decorators that we progrmmers can create according to our needs

# %%
# pythod are first class function
def func():
  print('hello')

a = func()
func()

# def modify(func,num):
#   return func(num) ## thsi is decorator

def square(num): # thsi is function
  return num**2

# modify(square,2)
# Out:
# hello
# hello

# %%
# simple example

def my_decorator(fun):
  def wrapper():
    print("****************")
    func()
    print("*****")
  return wrapper

def hello():
  print('hello')

def display():
  print('hello nitish')

a = my_decorator(hello)
a()

b = my_decorator(display)
b()
# Out:
# ****************
# hello
# *****
# ****************
# hello
# *****

# %%
# better syntax??
# simple example
def my_decorator(func):
  def wrapper():
    print("******")
    func()
    print("*****")
  return wrapper

@my_decorator
def hello():
  print('hello')
hello()
# Out:
# ******
# hello
# *****

# %%
# anything meaningful?
import time
def timer(func):
  def wrapper(*args):
    start = time.time()
    func(*args)
    print('time taken by',func.__name__,time.time()-start,'secs')
    return wrapper

@timer
def hello():
  print('hello world')
  time.sleep(2)


@timer
def square(num):
  time.sleep(1)
  print(num**2)

square(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1033/3528902843.py in <cell line: 0>()
#      19   print(num**2)
#      20
# ---> 21 square(2)
#
# TypeError: 'NoneType' object is not callable

# %%
# A big problem

# %%
@sanity_check(int)
def square(num):
  print(num**2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1033/2623553632.py in <cell line: 0>()
# ----> 1 @sanity_check(int)
#       2 def square(num):
#       3   print(num**2)
#
# TypeError: 'NoneType' object is not callable
