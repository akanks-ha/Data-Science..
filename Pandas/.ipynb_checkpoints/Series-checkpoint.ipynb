# %% [markdown]
# # Pandas' main goal ->
# * Data cleaning
# * Data analyse
# * Data Manipulation
#
# Pandas mean -> large panel data

# %% [markdown]
# # Use Case of pandas
#
# * Data Cleaning
# * Data Analysis
# * Data Transformation
# * Data Visualisation
# * Data Aggregation
# * File Handling
# * Data Filtering & Selection
# * Time Series Analysis

# %% [markdown]
# # Pandas Series
#
# A series is a one-dimensional labeled array capable of holding any data type.The axis labels are collectively called the index.
# vertically

# %% [markdown]
#  # Creating Series
#
#  There are multiple ways to create a pandas Series:

# %%
import numpy as np
import pandas as pd

# %%
# lables is known as index
labels = ['a','b','c']
my_list = [10,20,30]

arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
