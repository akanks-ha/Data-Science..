# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

# %%
df = pd.DataFrame(data)

# %%
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    929     95   John  January      Q1
# 1  2023-01-02       B   West    215     62   Mary  January      Q1
# 2  2023-01-03       C  North    674     71    Bob  January      Q1
# 3  2023-01-04       D  South    354     59  Alice  January      Q1
# 4  2023-01-05       A   East    740     83   John  January      Q1
# 5  2023-01-06       B   West    292     36   Mary  January      Q1
# 6  2023-01-07       C  North    694     77    Bob  January      Q1
# 7  2023-01-08       D  South    869     43  Alice  January      Q1
# 8  2023-01-09       A   East    233     31   John  January      Q1
# 9  2023-01-10       B   West    885     86   Mary  January      Q1
# 10 2023-01-11       C  North    136     28    Bob  January      Q1
# 11 2023-01-12       D  South    551     84  Alice  January      Q1
# 12 2023-01-13       A   East    386     61   John  January      Q1
# 13 2023-01-14       B   West    214     97   Mary  January      Q1
# 14 2023-01-15       C  North    232     37    Bob  January      Q1
# 15 2023-01-16       D  South    931     70  Alice  January      Q1
# 16 2023-01-17       A   East    491     80   John  January      Q1
# 17 2023-01-18       B   West    513     89   Mary  January      Q1
# 18 2023-01-19       C  North    963     14    Bob  January      Q1
# 19 2023-01-20       D  South    121     34  Alice  January      Q1

# %%
pd.pivot_table(df,values = 'Sales',index = 'Region',columns = 'Product')
# Out:
# Product      A      B      C      D
# Region
# East     555.8    NaN    NaN    NaN
# North      NaN    NaN  539.8    NaN
# South      NaN    NaN    NaN  565.2
# West       NaN  423.8    NaN    NaN

# %%
pd.pivot_table(df,values = 'Sales',index = 'Region',columns = 'Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     491.0    NaN    NaN    NaN
# North      NaN    NaN  674.0    NaN
# South      NaN    NaN    NaN  551.0
# West       NaN  292.0    NaN    NaN

# %% [markdown]
# ## use -> heatmap
# ## if you want to use your values which is not given in table use pivot table

# %%
pivot2 =pd.pivot_table(df,values=['Sales','Units'],index = 'Region',columns = 'Product') # using aggregation use only numeric
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     555.8    NaN    NaN    NaN  70.0   NaN   NaN   NaN
# North      NaN    NaN  539.8    NaN   NaN   NaN  45.4   NaN
# South      NaN    NaN    NaN  565.2   NaN   NaN   NaN  58.0
# West       NaN  423.8    NaN    NaN   NaN  74.0   NaN   NaN

# %% [markdown]
#  # Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
