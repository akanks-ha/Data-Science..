# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # Numpy:

# %% [raw]
# Now do you know how NumPy was made
# Numpy is written in C, which is compiled and super fast.
# This is the main reason Numpy is up to 50x faster than Python lists.

# %% [markdown]
# # task -> Numpy Arrays,
#         Numpy Indexing,
#         Numpy Operations,
#         Numpy Exercise

# %% [markdown]
# # Numpy Arrays :
#
# When we were doing python we had the data structure list, and Numpy is famopus for arays.

# %% [markdown]
# ![image.png](attachment:e1809b3a-ab8b-403e-9241-867cf9d5089b.png)

# %% [markdown]
# # import numpy

# %%
import numpy as np

# %% [markdown]
# # Basic Array creation

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
a = [1,2,3.5,4,'hello']
a
# Out:
# [1, 2, 3.5, 4, 'hello']

# %%
np.array(a) # all data type has been changed to string
# Out:
# array(['1', '2', '3.5', '4', 'hello'], dtype='<U32')

# %%
np.array([1,2,3.5]) # isme sblo float me change kr diya agar koi aisa hai jiske vjah se disturbance aa rha hai usi ke according sb change kr dega
# Out:
# array([1. , 2. , 3.5])
